# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2.  線性迴歸訓練資料、測試資料
#
# 80%  training data, 20%  testing data ==> 先利用此來驗證各種模型(演算法)的好壞及調好到最佳參數
# 之後可以利用由這個80%的訓練資料所得的模型後,拿100%資料re-train模型以得到最佳模型 (此model會更佳fit data)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x = np.linspace(0, 5, 50)
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=20)
print(x_train)
# Out:
# [4.08163265 1.73469388 1.83673469 0.         2.75510204 3.36734694
#  3.67346939 4.28571429 1.02040816 0.30612245 4.18367347 1.32653061
#  4.69387755 0.20408163 3.87755102 3.97959184 0.51020408 4.3877551
#  3.7755102  3.06122449 0.6122449  2.95918367 1.63265306 1.93877551
#  5.         4.48979592 2.14285714 3.26530612 3.46938776 0.71428571
#  2.24489796 1.12244898 2.04081633 0.91836735 4.89795918 2.85714286
#  3.16326531 1.53061224 2.65306122 3.57142857]

# %%
y
# Out:
# array([0.24946325, 0.72489204, 1.09506794, 1.56622761, 1.13890105,
#        1.78701836, 1.87936232, 2.18482903, 1.78691188, 2.0492145 ,
#        1.3769049 , 1.72598072, 3.09414285, 1.78824799, 2.10795393,
#        2.93016068, 1.58426235, 2.90210143, 2.97230283, 3.42165143,
#        3.02744706, 3.4887549 , 4.00192492, 2.85142243, 4.0189514 ,
#        4.23421635, 3.54127871, 4.64564148, 3.47383697, 3.91346631,
#        3.20078263, 5.14955022, 6.33911273, 6.09471987, 5.58267456,
#        5.10022869, 5.11637224, 5.31517627, 6.0995741 , 5.92835468,
#        6.00274025, 5.2094395 , 6.27348917, 6.57839851, 6.19516095,
#        4.9483897 , 6.54190531, 6.58572651, 5.21767548, 6.53517681])

# %%
plt.scatter(x_train, y_train)

# %% [markdown]
# #### 用訓練資料來 fit 函數
#
# 記得現在我們只用 80% 的資料去訓練。

# %%
regr = LinearRegression()
X_train = x_train.reshape(-1,1)
regr.fit(X_train,y_train)
print('Coefficients: ', regr.coef_)
print('interception: ', regr.intercept_)
# Out:
# Coefficients:  [1.21272225]
# interception:  0.7904017973933715

# %%
Y_train = regr.predict(X_train)

# %%
mse = np.sum((Y_train-y_train)**2) / len(y_train)
print(mse)
# Out:
# 0.37964349328641833

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, Y_train, 'r')

# %% [markdown]
# #### test with test data

# %%
X_test = x_test.reshape(-1,1)
Y_test = regr.predict(X_test)

print(Y_test)
# Out:
# [2.27536781 2.52286215 1.28539047 1.78037914 6.35902436 0.91414897
#  3.884081   3.76033383 6.6065187  3.63658666]

# %% [markdown]
# $$\widehat{y}=xw+b=w_{1}x_{1}+b$$

# %%
#Y=WX+b
W=regr.coef_
b=regr.intercept_
W*X_test+b
# Out:
# array([[2.27536781],
#        [2.52286215],
#        [1.28539047],
#        [1.78037914],
#        [6.35902436],
#        [0.91414897],
#        [3.884081  ],
#        [3.76033383],
#        [6.6065187 ],
#        [3.63658666]])

# %%
mse = np.sum((Y_test-y_test)**2) / len(y_test)
print(mse)
# Out:
# 0.3696144535627088

# %%
title='f(x)=1.2x+0.8'+',mse:'+str(round(mse,2))
plt.title(title)
plt.xlabel('x')
plt.ylabel('y')
#plt.grid(True)
plt.scatter(x_test, y_test,alpha=0.8,label='Ground Truth')
plt.scatter(x_test, Y_test, c='r', alpha=0.8,label='Predict')
plt.legend()
